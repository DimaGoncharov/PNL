# %%
import pandas as pd
import numpy as np
import csv

data = pd.read_csv('trades_month.csv')
data = data.sort_values(['time'])
new_km = []
pair = data['pair']
vol =  data['vol']
typ = data['type'] 
cost = data['cost']
price = data['price']
#находим кол-во пар и создаем список уникальных пар s
Gav = set()
for lin in data['pair']:
    Gav.add(lin)
s = list()
for n in Gav:
    s.append(n)
quantity_pairs = len(s)

#инициализируем рабочие словари
z = 0
while z < len(s):
    kaka[s[z]] = 0
    pepe[s[z]] = 0
    vanya[s[z]] = 0
    z += 1
#kaka = {s[0]: 0.0, s[1]:0.0, s[2]:0.0, s[3]:0.0, s[4]:0.0}
#pepe = {s[0]: 0.0, s[1]:0.0, s[2]:0.0, s[3]:0.0, s[4]:0.0}
#vanya = {s[0]: 0.0, s[1]:0.0, s[2]:0.0, s[3]:0.0, s[4]:0.0}

f_leg0 = 0
s_leg0 = 0

f_leg1 = 0
s_leg1 = 0

f_leg2 = 0
s_leg2 = 0

f_leg3 = 0
s_leg3 = 0

f_leg4 = 0
s_leg4 = 0

f_leg5 = 0
s_leg5 = 0

f_leg6 = 0
s_leg6 = 0

f_leg7 = 0
s_leg7 = 0

f_leg8 = 0
s_leg8 = 0




num = 0
for sim in pair:
    num += 1
e = 0
n = 0
Roma = {"XBTZEUR": 1, "TRXUSD": 0, "WAVESUSD": 0}


#def count(m):
 #   if typ[m] == 'buy':
  #          f_leg1 = f_leg1 + vol[m]
   #         s_leg1 = s_leg1 - cost[m]
   # else:
    #        f_leg1 = f_leg1 - vol[m]
     #       s_leg1 = s_leg1 + cost[m]   
#final = [0,0,0]
r = 0
while n < 31345:
    r = 0
    while r < len(s):
        if pair[n] == s[r]:
            if typ[n] == 'buy':
                kaka[s[r]] = vol[n] + kaka[s[r]]
                pepe[s[r]] = pepe[s[r]] - cost[n] 
            else:
                kaka[s[r]] = kaka[s[r]] - vol[n]
                pepe[s[r]] = pepe[s[r]] + cost[n]
            vanya[s[r]] = kaka[s[r]] * price[n] + pepe[s[r]]
        r += 1
    n += 1
    #if pair[n] == s[3]:
     #   if typ[n] == 'buy':
      #      f_leg3 = f_leg3 + vol[n]
       #     s_leg3 = s_leg3 - cost[n]
       # else:
        #    f_leg3 = f_leg3 - vol[n]
         #   s_leg3 = s_leg3 + cost[n]
    
    
Gav = set()
for lin in pair:
    Gav.add(lin)
#print(s[0],'\n', f_leg0, '\n', s_leg0)
#print(s[1],'\n', f_leg1, '\n', s_leg1)
#print(s[2],'\n', f_leg2, '\n', s_leg2)
#print(s[3],'\n', f_leg3, '\n', s_leg3)
#print(s[4],'\n', f_leg4, '\n', s_leg4)
#print(s[5],'\n', f_leg5, '\n', s_leg5)
s = list()
for n in Gav:
    s.append(n)
quantity_pairs = len(s)
print(quantity_pairs )
#print(s)
#print(kaka)
print(vanya)
# Out:
# 19
# {'XXBTZEUR': -107.80904024000165, 'XETHZEUR': -6.7043150083009095, 'WAVESUSD': 3.6743726469679814, 'BCHUSD': 1067.4991890000092, 'OMGUSD': -2.2516510772683205, 'XZECZUSD': 2.0000000006348273e-05, 'XETCZUSD': -0.08362572378212008, 'XXMRZUSD': -8.927401392400498, 'USDTZUSD': -1.8227750261758047, 'XETHZUSD': 741.8793978294052, 'EOSUSD': -0.3749596934140129, 'USDTEUR': 0.10269763819212585, 'XLTCZUSD': 37.32687861560021, 'XXRPZUSD': 0.07225779624474171, 'TRXUSD': -1.9861835709300522, 'DASHUSD': 15.078631638234583, 'XXBTZGBP': -0.18987000000015541, 'ADAUSD': -55.449481057768935, 'XXBTZUSD': -486.95875210407394}
